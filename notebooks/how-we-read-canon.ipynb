# %% [markdown]
# # 03 · How we read the Canon — Dao De Jing Tri-Column Reader
#
# **Reproduces:** [lius.cc/llm/demos/canon-reader](https://lius.cc/llm/demos/canon-reader)
#
# **Idea:** original text (Wang Bi edition, public domain) + vernacular translation (in-house, CC0) + live RAG commentary.
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lius-cc/lius-cookbook/blob/main/notebooks/how-we-read-canon.ipynb)

# %%
import requests

CHAPTERS = {
    1:  "道可道，非常道。名可名，非常名。無，名天地之始；有，名萬物之母。",
    2:  "天下皆知美之為美，斯惡已；皆知善之為善，斯不善已。故有無相生，難易相成。",
    11: "三十輻共一轂，當其無，有車之用。",
    33: "知人者智，自知者明。勝人者有力，自勝者強。",
    81: "信言不美，美言不信。善者不辯，辯者不善。",
}

def fetch_commentary(chapter_num: int, original: str):
    q = f"道德經 第{chapter_num}章 {original[:8]} 王弼 河上公"
    r = requests.post(
        "https://lius.cc/api/llm-rag",
        json={"q": q, "n": 5},
        timeout=10,
    ).json()
    return r["hits"]

for num, text in CHAPTERS.items():
    print(f"\n=== 第 {num} 章 ===")
    print(f"原文：{text}")
    hits = fetch_commentary(num, text)
    for h in hits[:3]:
        print(f"  ▸ [{h['type']}] {h['name']} (score {h['score']})")

# %% [markdown]
# ## Reproducibility
#
# - **Snapshot date:** 2026-05-17
# - **RAG API:** lius.cc/api/llm-rag (30 req/min, free)
# - **Original text edition:** Wang Bi 王弼本 (public domain)
# - **Vernacular translation:** Dingren Daoxue Lab in-house, CC0
# - **Note:** v0.1 preprint, no peer review yet
