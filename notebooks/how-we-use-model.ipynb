# %% [markdown]
# # 01 · How we use the Model
#
# Run Daoism-Qwen3.5-9B locally with LM Studio, Ollama, or vLLM. Apache 2.0.
#
# 📦 [Repo](https://github.com/lius-cc/lius-cookbook) · 🌐 [Live demos](https://lius.cc/llm/demos) · 📜 CC0 1.0 · v0.1 preprint (not peer-reviewed)
#
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lius-cc/lius-cookbook/blob/main/notebooks/how-we-use-model.ipynb)

# %%
# LM Studio (easiest, GUI)
# 1. Download from https://lmstudio.ai
# 2. Search 'lius-cc/Daoism-Qwen3.5-9B-GGUF'
# 3. Pick Q5_K_M (~6.5 GB) and chat.

# Ollama (CLI)
# $ ollama pull hf.co/lius-cc/Daoism-Qwen3.5-9B-GGUF:Q5_K_M
# $ ollama run hf.co/lius-cc/Daoism-Qwen3.5-9B-GGUF:Q5_K_M

# vLLM (production, 24GB VRAM+)
# $ pip install vllm
# $ vllm serve lius-cc/Daoism-Qwen3.5-9B \
#     --dtype bfloat16 --max-model-len 4096 --gpu-memory-utilization 0.85

# %% [markdown]
# ## Reproducibility
#
# - **Snapshot:** 2026-05-17
# - **Model:** `lius-cc/Daoism-Qwen3.5-9B` (Apache 2.0)
# - **Dataset:** `lius-cc/daoism-knowledge-rag@v1` (95,919 nodes, Apache 2.0)
# - **RAG API:** `https://lius.cc/api/llm-rag` (30 req/min, free)
# - v0.1 preprint — not yet peer-reviewed.
